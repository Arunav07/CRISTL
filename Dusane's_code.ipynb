# %% [markdown]
# <a href="https://colab.research.google.com/github/Arunav07/CRISTL-Project-1/blob/Anuja's-branch/Dusane's_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
import numpy as np
import pandas as pd
import tensorflow as tf


from PIL import Image
import glob
import natsort
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AX4XfWiP4aohrGbD6tzlc572jtCjEY45erYw8ttrWc-j4z_ZCGfFsBMussc
# Mounted at /content/gdrive

# %%
Images = glob.glob("/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/*.jpg")

# %%
Images = natsort.natsorted(Images,reverse=False)

# %%
#To check whether all images are read successfully or not.
print(Images)
print(type(Images))
print(len(Images))
# Out:
# ['/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000060.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000240.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000420.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000480.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000600.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000540.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000060_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000066_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000660.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000054_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000840.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000720.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000900.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000084_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000072_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000078_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000780.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000090_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0001020.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000096_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0001080.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000960.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000102_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0001260.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0001200.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0001140.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000114_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000120_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000126_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000108_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0001320.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000138_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0001380.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000132_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0001560.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0001620.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/ ...
# <class 'list'>
# 385

# %%
import matplotlib.pyplot as plt

# %%
im = tf.io.read_file(Images[1])# Read the image
im_decoded = tf.io.decode_jpeg(im) # Decode the image
img=tf.image.rgb_to_grayscale(im_decoded)
img = tf.image.central_crop(img, 0.85)
print(img.shape)
#img = tf.image.crop_to_bounding_box(img, offset_height = 0 , offset_width = 0 , target_height = 2422, target_width = 3380)
img = tf.image.resize(img, size=(256, 256))
img = np.asarray(img)
plt.imshow(np.squeeze(img))
#plt.imshow(img,cmap='gray')
plt.show()
# Out:
# (820, 1088, 1)

# %%
print(len(Images))
Image_array=[]
print(tf.io.read_file(Images[384]))
print(Images[384])
im_decoded = tf.io.decode_jpeg(tf.io.read_file(Images[1]))
img=tf.image.rgb_to_grayscale(im_decoded)
img = tf.image.central_crop(img, 0.85)
img = tf.image.resize(img, size=(256, 256))
img = np.asarray(img)
Image_array.append(img)
# Out:
# 385
# tf.Tensor(b'', shape=(), dtype=string)
# /content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000006_r.jpg

# %%
print(len(Images))
Image_array=[]
print(tf.io.read_file(Images[38]))
print(Images[38])
im_decoded = tf.io.decode_jpeg(tf.io.read_file(Images[1]))
img=tf.image.rgb_to_grayscale(im_decoded)
img = tf.image.central_crop(img, 0.85)
img = tf.image.resize(img, size=(256, 256))
img = np.asarray(img)
Image_array.append(img)
# Out:
# 385
# tf.Tensor(b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x03\xc4\x05\x00\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1e\x00\x00\x02\x02\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x01\x04\x00\x05\x06\x07\x08\t\n\xff\xc4\x00O\x10\x00\x02\x01\x02\x04\x03\x05\x06\x04\x05\x04\x01\x03\x01\x00\x13\x01\x02\x03\x04\x11\x00\x12!1\x05\x13A\x06\x07"Qa\x08\x142q\x81\x91#B\xa1\xf0\t\x15\xb1\xc1\xd13R\xe1\xf1$\x16Cb\nr\x82\x17%4\x92S\x18c\xa2\x83\x93\xb2&\'5s\xc2\xe2\xff\xc4\x00\x1b\x01\x00\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\
print(Image_data)
# Out:
# [[[[255.       ]
#    [255.       ]
#    [255.       ]
#    ...
#    [255.       ]
#    [255.       ]
#    [254.43848  ]]
#
#   [[255.       ]
#    [255.       ]
#    [255.       ]
#    ...
#    [255.       ]
#    [255.       ]
#    [254.88574  ]]
#
#   [[255.       ]
#    [255.       ]
#    [255.       ]
#    ...
#    [253.98438  ]
#    [254.43066  ]
#    [254.00586  ]]
#
#   ...
#
#   [[ 69.68457  ]
#    [ 60.71582  ]
#    [ 51.19043  ]
#    ...
#    [ 73.30957  ]
#    [ 78.01074  ]
#    [ 75.336914 ]]
#
#   [[ 82.67578  ]
#    [ 75.51465  ]
#    [ 56.874023 ]
#    ...
#    [ 77.03711  ]
#    [ 80.31445  ]
#    [ 75.83887  ]]
#
#   [[ 73.02637  ]
#    [ 73.85547  ]
#    [ 69.32715  ]
#    ...
#    [ 74.52734  ]
#    [ 80.21875  ]
#    [ 74.95117  ]]]
#
#
#  [[[ 14.1484375]
#    [ 12.887695 ]
#    [ 12.796875 ]
#    ...
#    [170.3164   ]
#    [202.47363  ]
#    [207.30762  ]]
#
#   [[ 12.260742 ]
#    [ 13.516602 ]
#    [ 12.       ]
#    ...
#    [198.45215  ]
#    [196.6582   ]
#    [206.39551  ]]
#
#   [[ 10.865234 ]
#    [ 17.438477 ]
#    [ 12.384766 ]
#    ...
#    [193.82715  ]
#    [201.13086  ]
#    [168.0957   ]]
#
#   ...
#
#   [[ 22.930664 ]
#    [ 21.996094 ]
#    [ 24.42871  ]
#    ...
#    [ 25.722656 ]
#    [ 22.90039  ]
#    [ 22.59668  ]]
#
#   [[ 20.608398 ]
#    [ 23.141602 ]
#    [ 20.875    ]
#    ...
#    [ 22.25     ]
#    [ 24.141602 ]
#    [ 20.995117 ]]
#
#   [[ 21.95996  ]
#    [ 23.65039  ]
#    [ 21.786133 ]
#    ...
#    [ 22.326172 ]
#    [ 20.30664  ]
#    [ 23.00586  ]]]
#
#
#  [[[129.3252   ]
#    [202.18066  ]
#    [212.2627   ]
#    ...
#    [215.65332  ]
#    [224.08789  ]
#    [216.35938  ]]
#
#   [[247.95215  ]
#    [150.3086   ]
#    [136.10254  ]
#    ...
#    [218.47656  ]
#    [226.40234  ]
#    [218.22461  ]]
#
#   [[228.48828  ]
#    [154.49707  ]
#    [147.42188  ]
#    ...
#    [216.17383  ]
#    [215.88965  ]
#    [212.5957   ]]
#
#   ...
#
#   [[ 23.61914  ]
#    [ 22.109375 ]
#    [ 21.783203 ]
#    ...
#    [ 17.67871  ]
#    [ 16.517578 ]
#    [ 18.361328 ]]
#
#   [[ 19.49414  ]
#    [ 18.288086 ]
#    [ 23.625977 ]
#    ...
#    [ 20.733398 ]
#    [ 18.478516 ]
#    [ 16.89746  ]]
#
#   [[ 21.811523 ]
#    [ 19.929688 ]
#    [ 24.492188 ]
#    ...
#    [ 19.012695 ]
#    [ 19.010742 ]
#    [ 18.711914 ]]]
#
#
#  ...
#
#
#  [[[ 44.88086  ]
#    [ 22.6875   ]
#    [ 23.516602 ]
#    ...
#    [216.33887  ]
#    [207.28516  ]
#    [235.25879  ]]
#
#   [[ 41.989258 ]
#    [ 12.109375 ]
#    [ 33.393555 ]
#    ...
#    [216.64062  ]
#    [202.54785  ]
#    [233.1123   ]]
#
#   [[ 38.399414 ]
#    [ 15.583008 ]
#    [ 17.384766 ]
#    ...
#    [210.18555  ]
#    [205.85742  ]
#    [234.78516  ]]
#
#   ...
#
#   [[ 34.317383 ]
#    [ 32.41504  ]
#    [ 34.152344 ]
#    ...
#    [ 31.274414 ]
#    [ 26.670898 ]
#    [ 30.276367 ]]
#
#   [[ 34.65625  ]
#    [ 36.365234 ]
#    [ 36.114258 ]
#    ...
#    [ 29.99414  ]
#    [ 24.266602 ]
#    [ 33.179688 ]]
#
#   [[ 35.161133 ]
#    [ 37.504883 ]
#    [ 37.748047 ]
#    ...
#    [ 29.976562 ]
#    [ 27.279297 ]
#    [ 29.864258 ]]]
#
#
#  [[[ 60.541016 ]
#    [ 56.597656 ]
#    [ 46.995117 ]
#    ...
#    [247.22656  ]
#    [249.33887  ]
#    [252.43848  ]]
#
#   [[ 43.438477 ]
#    [ 48.250977 ]
#    [100.22656  ]
#    ...
#    [248.125    ]
#    [250.42969  ]
#    [254.       ]]
#
#   [[ 46.87793  ]
#    [ 80.09277  ]
#    [ 51.592773 ]
#    ...
#    [248.       ]
#    [251.74219  ]
#    [252.44043  ]]
#
#   ...
#
#   [[ 43.569336 ]
#    [ 43.958008 ]
#    [ 44.29004  ]
#    ...
#    [ 44.265625 ]
#    [ 38.456055 ]
#    [ 40.740234 ]]
#
#   [[ 51.521484 ]
#    [ 42.3584   ]
#    [ 40.908203 ]
#    ...
#    [ 36.239258 ]
#    [ 36.146484 ]
#    [ 38.265625 ]]
#
#   [[ 46.208008 ]
#    [ 42.381836 ]
#    [ 45.989258 ]
#    ...
#    [ 42.121094 ]
#    [ 43.479492 ]
#    [ 39.563477 ]]]
#
#
#  [[[193.09668  ]
#    [190.67383  ]
#    [192.55371  ]
#    ...
#    [203.38086  ]
#    [202.31152  ]
#    [200.09375  ]]
#
#   [[193.89062  ]
#    [188.47266  ]
#    [186.88184  ]
#    ...
#    [208.40234  ]
#    [200.37305  ]
#    [203.13867  ]]
#
#   [[190.45996  ]
#    [195.78223  ]
#    [187.84375  ]
#    ...
#    [192.62695  ]
#    [199.34668  ]
#    [200.62793  ]]
#
#   ...
#
#   [[ 27.702148 ]
#    [ 27.396484 ]
#    [ 24.476562 ]
#    ...
#    [ 30.988281 ]
#    [ 28.38086  ]
#    [ 29.507812 ]]
#
#   [[ 28.413086 ]
#    [ 26.738281 ]
#    [ 26.96289  ]
#    ...
#    [ 30.266602 ]
#    [ 28.038086 ]
#    [ 32.390625 ]]
#
#   [[ 30.296875 ]
#    [ 24.128906 ]
#    [ 27.706055 ]
#    ...
#    [ 29.972656 ]
#    [ 27.529297 ]
#    [ 30.347656 ]]]]
