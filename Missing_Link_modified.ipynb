# %% [markdown]
# <a href="https://colab.research.google.com/github/Arunav07/CRISTL-Project-1/blob/Atharva_D's-Branch/Missing_Link_modified.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import glob
import natsort
import numpy as np
import pandas as pd
import tensorflow as tf
from PIL import Image
import xml.etree.ElementTree as ET
import csv

# %%
Labels=[]
print(Labels)
# Out:
# []

# %%
f = open('/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000006_r.xml') 
root = ET.parse(f)

# Create and open csv
xml_data_to_csv = open('Out.csv','w')

# Create the variable to write the csv
csv_writer = csv.writer(xml_data_to_csv)

# creating the columns for the table
Table = []
Table.append([('Labels'),('Co-ordinates')])
for obj in root.findall('object'):
    bndbox: ET.Element = obj.find('bndbox')
    name = obj.find('name').text
    xmin, xmax, ymin, ymax = [int(bndbox.find(x).text) for x in ['xmin', 'xmax', 'ymin', 'ymax']]
    coords = [(x, y) for x in [xmin, xmax] for y in [ymin, ymax]]
    Table.append([(name),(coords)])

# adding too csv
csv_writer.writerows(Table)

# close the csv file
xml_data_to_csv.close()      
  
# close the .xml file
f.close()
la=pd.read_csv("Out.csv")
lab=la.Labels.values
labe=tuple(lab)
Labels.append(labe)

# %%
print(Labels)
# Out:
# [('truck', 'person', 'autorickshaw', 'person', 'car')]

# %%
# la=pd.read_csv("Out.csv")
# lab=la.Labels.values
# #print(lab)
# labe=tuple(lab)
# #print(labe)
# Labels_array.append(labe)
# print(Labels_array,len(Labels_array))

# %%
count = 0
for i in range(6,17400,6):
  try:
    count += 1
    annot_path = '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/'
    path_name = annot_path + str(i).zfill(6) + "_r.xml"
    f = open(path_name) 
    root = ET.parse(f)

    # Create and open csv
    xml_data_to_csv = open('Out.csv','w')

    # Create the variable to write the csv
    csv_writer = csv.writer(xml_data_to_csv)

    # creating the columns for the table
    Table = []
    Table.append([('Labels'),('Co-ordinates')])

    for obj in root.findall('object'):
        bndbox: ET.Element = obj.find('bndbox')
        name = obj.find('name').text
        xmin, xmax, ymin, ymax = [int(bndbox.find(x).text) for x in ['xmin', 'xmax', 'ymin', 'ymax']]
        coords = [(x, y) for x in [xmin, xmax] for y in [ymin, ymax]]
        Table.append([(name),(coords)])

    # adding too csv
    csv_writer.writerows(Table)

    # close the csv file
    xml_data_to_csv.close()      
  
    # close the .xml file
    f.close()
    la=pd.read_csv("Out.csv")
    lab=la.Labels.values
    labe=tuple(lab)
    Labels.append(labe)

  except FileNotFoundError:
    continue

# %%
print(Labels)
print(len(Labels))
# Out:
# [('truck', 'person', 'autorickshaw', 'person', 'car'), ('truck', 'person', 'autorickshaw', 'person', 'car'), ('truck', 'truck', 'autorickshaw', 'person', 'person'), ('truck', 'truck'), ('truck', 'truck', 'autorickshaw'), ('truck', 'autorickshaw', 'truck'), ('truck', 'truck'), ('truck', 'truck', 'person', 'autorickshaw'), ('truck', 'truck', 'autorickshaw', 'person'), ('truck', 'truck', 'autorickshaw', 'person'), ('motorcycle', 'rider', 'autorickshaw', 'truck', 'person', 'person'), ('person', 'person', 'motorcycle', 'rider', 'truck', 'autorickshaw', 'person'), ('motorcycle', 'rider', 'truck', 'person', 'person', 'person'), ('motorcycle', 'rider'), ('motorcycle', 'rider'), ('bus',), ('bus',), ('autorickshaw', 'car', 'bus', 'bicycle', 'rider'), ('autorickshaw', 'bus', 'bicycle', 'rider', 'vehicle fallback'), ('autorickshaw', 'vehicle fallback', 'bus'), ('autorickshaw', 'vehicle fallback', 'bicycle', 'rider'), ('autorickshaw', 'vehicle fallback', 'bicycle', 'rider'), ('vehicle fallback', 'motorcycle', 'rider', 'bicycle', 'rider', 'autorickshaw', 'motorcycle', 'rider'), ('vehicle fallback', 'motorcycle', 'vehicle fallback', 'bicycle', 'rider', 'motorcycle', 'rider', 'rider', 'autorickshaw'), ('vehicle fallback', 'motorcycle', 'rider', 'bicycle', 'rider', 'vehicle fallback', 'motorcycle', 'rider', 'rider'), ('motorcycle', 'rider', 'motorcycle', 'rider', 'bicycle', 'rider'), ('motorcycle', 'motorcycle', 'rider', 'rider'), ('motorcycle', 'motorcycle', 'rider', 'rider'), ('motorcycle', 'rider', 'rider'), ('autorickshaw', 'bicycle', 'rider'), ('vehicle fallback', 'autorickshaw', 'person', 'motorcycle', 'rider', 'motorcycle', 'rider', 'rider'), ('person', 'vehicle fallback', 'car', 'person', 'vehicle fallback', 'person'), ('car', 'motorcycle', 'motorcycle', 'bicycle', 'rider', 'rider', 'bicycle', 'rider', 'rider'), ('car', 'motorcycle', 'rider', 'bicycle', 'rider', 'bicycle', 'rider', 'car'), ('motorcycle', 'rider', 'truck', 'car', 'car', 'bicycle', 'rider'), ('motorcycle', 'rider', 'truck', 'car', 'bicycle', 'rider'), ('motorcycle', 'rider', 'car', 'truck', 'car'), ('motorcycle', 'rider', 'car', 'truck', 'traffic sign'), ('traffic sign', 'motorcycle', 'rider', 'car'), ('traffic sign', 'motorcycle', 'rider'), ('traffic sign', 'motorcycle', 'rider'), ('motorcycle', 'rider'), ('bus',), ('bus',), ('person', 'motorcycle', 'rider'), ('motorcycle', 'rider'), ('car', 'autorickshaw', 'motorcycle', 'rider', 'motorcycle', 'rider'), ('autorickshaw', 'car', 'motorcycle', 'rider'), ('autorickshaw', 'car', 'motorcycle', 'rider'), ('autorickshaw', 'bicycle', 'rider', 'car', 'motorcycle', 'rider'), ('autorickshaw', 'motorcycle', 'motorcycle', 'rider', 'rider', 'car'), ('autorickshaw', 'motorcycle', 'rider', 'motorcycle', 'rider', 'car'), ('autorickshaw', 'motorcycle', 'rider', 'car'), ('autorickshaw', 'motorcycle', 'rider', 'car'), ('autorickshaw', 'car', 'motorcycle', 'rider'), ('car', 'motorcycle', 'rider'), ('truck', 'autorickshaw', 'car', 'motorcycle', 'rider'), ('autorickshaw', 'car', 'car', 'motorcycle', 'rider'), ('autorickshaw', 'truck', 'motorcycle', 'car', 'car', 'rider', 'rider'), ('car', 'car', 'truck', 'car', 'motorcycle', 'rider', 'rider'), ('truck', 'truck', 'motorcycle', 'truck', 'rider', 'car', 'motorcycle', 'motorcycle', 'rider', 'rider'), ('autorickshaw', 'car', 'car', 'car', 'bus', 'motorcycle', 'rider', 'rider'), ('autorickshaw', 'car', 'car', 'car', 'motorcycle', 'rider', 'rider', 'motorcycle', 'rider', 'rider', 'bus'), ('autorickshaw', 'car', 'car', 'car', 'motorcycle', 'rider', 'rider'), ('vehicle fallback', 'car', 'car', 'car', 'car', 'motorcycle', 'rider', 'rider'), ('vehicle fallback', 'car', 'motorcycle', 'rider', 'motorcycle', 'rider', 'rider'), ('autorickshaw', 'car', 'vehicle fallback', 'motorcycle', 'rider', 'rider'), ('vehicle fallback', 'autorickshaw', 'car'), ('vehicle fallback', 'car'), ('truck', 'vehicle fallback', 'car'), ('truck', 'car'), ('truck', 'autorickshaw', 'car'), ('truck', 'autorickshaw', 'car'), ('truck',  ...
# 183

# %%
count=0
for i in Labels:
  count=count+len(i)
print(count)
# Out:
# 1062

# %%
Images = glob.glob("/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/*.jpg")
Images = natsort.natsorted(Images,reverse=False)

# %%
print(Images)
print(len(Images))
# Out:
# ['/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000006_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000054_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000060.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000060_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000066_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000072_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000078_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000084_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000090_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000096_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000102_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000108_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000114_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000120_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000126_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000132_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000138_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000144_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000150_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000156_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000162_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000168_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000174_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000180_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000186_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000192_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000198_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000204_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000210_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000228_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000240.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000240_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000258_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000276_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000288_r.jpg', '/content/gdrive/My Drive/IDD_Detection/JPEGImages/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000294_r.jpg', '/content/gdrive/My Drive/IDD_Detection/J ...
# 385

# %%
Labels_data=glob.glob("/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/*.xml")
Labels_data = natsort.natsorted(Labels_data,reverse=False)

# %%
print(Labels_data)
print(len(Labels_data))
# Out:
# ['/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000006_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000054_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000060.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000060_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000066_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000072_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000078_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000084_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000090_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000096_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000102_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000108_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000114_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000120_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000126_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000132_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000138_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000144_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000150_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000156_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000162_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000168_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000174_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000180_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000186_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000192_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000198_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000204_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000210_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000228_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/0000240.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000240_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000258_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000276_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000288_r.xml', '/content/gdrive/My Drive/IDD_Detection/Annotations/frontFar/BLR-2018-03-22_17-39-26_2_frontFar/000294_r.xml', '/con ...
# 385

# %%
Labels=[]
print(Labels)
# Out:
# []

# %%
for i in Labels_data:
  f = open(i) 
  root = ET.parse(f)

  # Create and open csv
  xml_data_to_csv = open('Out.csv','w')

  # Create the variable to write the csv
  csv_writer = csv.writer(xml_data_to_csv)

  # creating the columns for the table
  Table = []
  Table.append([('Labels'),('Co-ordinates')])
  for obj in root.findall('object'):
      bndbox: ET.Element = obj.find('bndbox')
      name = obj.find('name').text
      xmin, xmax, ymin, ymax = [int(bndbox.find(x).text) for x in ['xmin', 'xmax', 'ymin', 'ymax']]
      coords = [(x, y) for x in [xmin, xmax] for y in [ymin, ymax]]
      Table.append([(name),(coords)])

  # adding too csv
  csv_writer.writerows(Table)

  # close the csv file
  xml_data_to_csv.close()      
    
  # close the .xml file
  f.close()
  la=pd.read_csv("Out.csv")
  lab=la.Labels.values
  labe=tuple(lab)
  Labels.append(labe)

# %%
print(len(Labels))
# Out:
# 385

# %%
print(Labels)
# Out:
# [('truck', 'person', 'autorickshaw', 'person', 'car'), ('truck', 'truck', 'autorickshaw', 'person', 'person'), ('truck', 'person', 'autorickshaw', 'person', 'car', 'person', 'person'), ('truck', 'truck'), ('truck', 'truck', 'autorickshaw'), ('truck', 'autorickshaw', 'truck'), ('truck', 'truck'), ('truck', 'truck', 'person', 'autorickshaw'), ('truck', 'truck', 'autorickshaw', 'person'), ('truck', 'truck', 'autorickshaw', 'person'), ('motorcycle', 'rider', 'autorickshaw', 'truck', 'person', 'person'), ('person', 'person', 'motorcycle', 'rider', 'truck', 'autorickshaw', 'person'), ('motorcycle', 'rider', 'truck', 'person', 'person', 'person'), ('motorcycle', 'rider'), ('motorcycle', 'rider'), ('bus',), ('bus',), ('autorickshaw', 'car', 'bus', 'bicycle', 'rider'), ('autorickshaw', 'bus', 'bicycle', 'rider', 'vehicle fallback'), ('autorickshaw', 'vehicle fallback', 'bus'), ('autorickshaw', 'vehicle fallback', 'bicycle', 'rider'), ('autorickshaw', 'vehicle fallback', 'bicycle', 'rider'), ('vehicle fallback', 'motorcycle', 'rider', 'bicycle', 'rider', 'autorickshaw', 'motorcycle', 'rider'), ('vehicle fallback', 'motorcycle', 'vehicle fallback', 'bicycle', 'rider', 'motorcycle', 'rider', 'rider', 'autorickshaw'), ('vehicle fallback', 'motorcycle', 'rider', 'bicycle', 'rider', 'vehicle fallback', 'motorcycle', 'rider', 'rider'), ('motorcycle', 'rider', 'motorcycle', 'rider', 'bicycle', 'rider'), ('motorcycle', 'motorcycle', 'rider', 'rider'), ('motorcycle', 'motorcycle', 'rider', 'rider'), ('motorcycle', 'rider', 'rider'), ('autorickshaw', 'bicycle', 'rider'), ('truck', 'truck', 'person', 'car', 'person', 'autorickshaw', 'autorickshaw', 'autorickshaw', 'autorickshaw', 'motorcycle'), ('vehicle fallback', 'autorickshaw', 'person', 'motorcycle', 'rider', 'motorcycle', 'rider', 'rider'), ('person', 'vehicle fallback', 'car', 'person', 'vehicle fallback', 'person'), ('car', 'motorcycle', 'motorcycle', 'bicycle', 'rider', 'rider', 'bicycle', 'rider', 'rider'), ('car', 'motorcycle', 'rider', 'bicycle', 'rider', 'bicycle', 'rider', 'car'), ('motorcycle', 'rider', 'truck', 'car', 'car', 'bicycle', 'rider'), ('motorcycle', 'rider', 'truck', 'car', 'bicycle', 'rider'), ('motorcycle', 'rider', 'car', 'truck', 'car'), ('motorcycle', 'rider', 'car', 'truck', 'traffic sign'), ('traffic sign', 'motorcycle', 'rider', 'car'), ('traffic sign', 'motorcycle', 'rider'), ('traffic sign', 'motorcycle', 'rider'), ('motorcycle', 'rider'), ('bus',), ('bus',), ('person', 'motorcycle', 'rider'), ('motorcycle', 'rider'), ('car', 'autorickshaw', 'motorcycle', 'rider', 'motorcycle', 'rider'), ('autorickshaw', 'car', 'motorcycle', 'rider'), ('autorickshaw', 'car', 'motorcycle', 'rider'), ('autorickshaw', 'bicycle', 'rider', 'car', 'motorcycle', 'rider'), ('autorickshaw', 'motorcycle', 'motorcycle', 'rider', 'rider', 'car'), ('autorickshaw', 'motorcycle', 'rider', 'motorcycle', 'rider', 'car'), ('autorickshaw', 'motorcycle', 'rider', 'car'), ('vehicle fallback', 'truck', 'person', 'truck', 'autorickshaw', 'person', 'truck'), ('autorickshaw', 'motorcycle', 'rider', 'car'), ('autorickshaw', 'car', 'motorcycle', 'rider'), ('car', 'motorcycle', 'rider'), ('truck', 'autorickshaw', 'car', 'motorcycle', 'rider'), ('autorickshaw', 'car', 'car', 'motorcycle', 'rider'), ('autorickshaw', 'truck', 'motorcycle', 'car', 'car', 'rider', 'rider'), ('car', 'car', 'truck', 'car', 'motorcycle', 'rider', 'rider'), ('truck', 'truck', 'motorcycle', 'truck', 'rider', 'car', 'motorcycle', 'motorcycle', 'rider', 'rider'), ('vehicle fallback', 'truck', 'truck', 'person', 'person', 'truck'), ('autorickshaw', 'car', 'car', 'car', 'bus', 'motorcycle', 'rider', 'rider'), ('autorickshaw', 'car', 'car', 'car', 'motorcycle', 'rider', 'rider', 'motorcycle', 'rider', 'rider', 'bus'), ('autorickshaw', 'car', 'car', 'car', 'motorcycle', 'rider', 'rider'), ('vehicle fallback', 'car', 'car', 'car', 'car', 'motorcycle', 'rider', 'rider'), ('vehicle fallback', 'car', 'motorcycle', 'rider', 'motorcycle', 'ride ...
